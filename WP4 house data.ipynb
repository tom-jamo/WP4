# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Multi_home_inputs.csv')
df2 = pd.read_csv('multi_home_variables.csv')
# Out:
# C:\Users\Tom.Jamieson\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (6,7) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df.head()
# Out:
#    Home number  Property  Substation Archetype Home name Parent prefix  \
# 0            1         1           1         A     1-1-A           NaN
# 1            2         1           1         A     1-2-A           NaN
# 2            3         1           1         A     1-3-A           NaN
# 3            4         1           1         A     1-4-A           NaN
# 4            5         1           1         A     1-5-A           NaN
#
#   Data prefix Expression prefix
# 0         NaN               NaN
# 1         NaN               NaN
# 2         NaN               NaN
# 3         NaN               NaN
# 4         NaN               NaN

# %%
df2.head(15)
# Out:
#     Property             Collection        Parent Object         Child Object  \
# 0          1             Purchasers               System        - Elec Demand
# 1          2             Purchasers               System        - Elec Demand
# 2          3             Purchasers               System        - Elec Demand
# 3          4             Purchasers               System        - Elec Demand
# 4          5             Purchasers               System          - Heat Loss
# 5          6             Purchasers               System          - Heat Loss
# 6          7             Purchasers               System   - Hot Water Demand
# 7          8             Purchasers               System   - Hot Water Demand
# 8          9  Constraint.Purchasers          - Heat Loss          - Heat Loss
# 9         10  Constraint.Purchasers   - Hot Water Demand   - Hot Water Demand
# 10        11             Purchasers               System        - Elec Demand
# ...

# %%
df_merge = df.merge(df2, on='Property')

# %%
pd.set_option('display.max_columns', None)
df_merge.head()
# Out:
#    Home number  Property  Substation Archetype Home name Parent prefix  \
# 0            1         1           1         A     1-1-A           NaN
# 1            2         1           1         A     1-2-A           NaN
# 2            3         1           1         A     1-3-A           NaN
# 3            4         1           1         A     1-4-A           NaN
# 4            5         1           1         A     1-5-A           NaN
#
#   Data prefix Expression prefix  Collection Parent Object    Child Object  \
# 0         NaN               NaN  Purchasers        System   - Elec Demand
# 1         NaN               NaN  Purchasers        System   - Elec Demand
# 2         NaN               NaN  Purchasers        System   - Elec Demand
# 3         NaN               NaN  Purchasers        System   - Elec Demand
# 4         NaN               NaN  Purchasers        System   - Elec Demand
#
#       Property.1 Value Data File   Units  Band  Date From  Date To  Timeslice  \
# ...

# %%
df_merge['Child Object 2'] = df_merge['Home name'] + df_merge['Child Object']
df_merge.head()
# Out:
#    Home number  Property  Substation Archetype Home name Parent prefix  \
# 0            1         1           1         A     1-1-A           NaN
# 1            2         1           1         A     1-2-A           NaN
# 2            3         1           1         A     1-3-A           NaN
# 3            4         1           1         A     1-4-A           NaN
# 4            5         1           1         A     1-5-A           NaN
#
#   Data prefix Expression prefix  Collection Parent Object    Child Object  \
# 0         NaN               NaN  Purchasers        System   - Elec Demand
# 1         NaN               NaN  Purchasers        System   - Elec Demand
# 2         NaN               NaN  Purchasers        System   - Elec Demand
# 3         NaN               NaN  Purchasers        System   - Elec Demand
# 4         NaN               NaN  Purchasers        System   - Elec Demand
#
#       Property.1 Value Data File   Units  Band  Date From  Date To  Timeslice  \
# ...

# %%
df_merge['Child Object'] = df_merge['Child Object 2']
df_merge.head()
# Out:
#    Home number  Property  Substation Archetype Home name Parent prefix  \
# 0            1         1           1         A     1-1-A           NaN
# 1            2         1           1         A     1-2-A           NaN
# 2            3         1           1         A     1-3-A           NaN
# 3            4         1           1         A     1-4-A           NaN
# 4            5         1           1         A     1-5-A           NaN
#
#   Data prefix Expression prefix  Collection Parent Object  \
# 0         NaN               NaN  Purchasers        System
# 1         NaN               NaN  Purchasers        System
# 2         NaN               NaN  Purchasers        System
# 3         NaN               NaN  Purchasers        System
# 4         NaN               NaN  Purchasers        System
#
#           Child Object     Property.1 Value Data File   Units  Band  \
# 0  1-1-A - Elec Demand  Price Setting    No       NaN  Yes/No     1
# ...

# %%
df_merge_clean = df_merge[['Collection', 'Parent Object', 'Child Object', 'Property.1', 'Value', 'Data File', 'Units', 'Band', 'Date From', 'Date To', 'Timeslice', 'Action', 'Expression', 'Scenario']]

# %%
df_merge_clean.head()
# Out:
#    Collection Parent Object         Child Object     Property.1 Value  \
# 0  Purchasers        System  1-1-A - Elec Demand  Price Setting    No
# 1  Purchasers        System  1-2-A - Elec Demand  Price Setting    No
# 2  Purchasers        System  1-3-A - Elec Demand  Price Setting    No
# 3  Purchasers        System  1-4-A - Elec Demand  Price Setting    No
# 4  Purchasers        System  1-5-A - Elec Demand  Price Setting    No
#
#   Data File   Units  Band  Date From  Date To  Timeslice Action Expression  \
# 0       NaN  Yes/No     1        NaN      NaN        NaN      =        NaN
# 1       NaN  Yes/No     1        NaN      NaN        NaN      =        NaN
# 2       NaN  Yes/No     1        NaN      NaN        NaN      =        NaN
# 3       NaN  Yes/No     1        NaN      NaN        NaN      =        NaN
# 4       NaN  Yes/No     1        NaN      NaN        NaN      =        NaN
#
#   Scenario
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN

# %%
df_merge_clean.tail()
# Out:
#        Collection Parent Object            Child Object  Property.1 Value  \
# 85912  Purchasers        System   91-6605-H - Heat Loss  Fixed Load     0
# 85913  Purchasers        System   93-6606-H - Heat Loss  Fixed Load     0
# 85914  Purchasers        System   94-6607-H - Heat Loss  Fixed Load     0
# 85915  Purchasers        System   95-6608-H - Heat Loss  Fixed Load     0
# 85916  Purchasers        System  117-6609-H - Heat Loss  Fixed Load     0
#
#                Data File Units  Band  Date From  Date To  Timeslice Action  \
# 85912  _Hot Water Demand    MW     1        NaN      NaN        NaN      =
# 85913  _Hot Water Demand    MW     1        NaN      NaN        NaN      =
# 85914  _Hot Water Demand    MW     1        NaN      NaN        NaN      =
# 85915  _Hot Water Demand    MW     1        NaN      NaN        NaN      =
# 85916  _Hot Water Demand    MW     1        NaN      NaN        NaN      =
#
#       Expression        Scenario
# 85912        NaN  No Stochastics
# ...

# %%
df_merge_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 85917 entries, 0 to 85916
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Collection     85917 non-null  object
#  1   Parent Object  85917 non-null  object
#  2   Child Object   85917 non-null  object
#  3   Property.1     85917 non-null  object
#  4   Value          85917 non-null  object
#  5   Data File      19827 non-null  object
#  6   Units          85917 non-null  object
#  7   Band           85917 non-null  int64
#  8   Date From      0 non-null      float64
#  9   Date To        0 non-null      float64
#  10  Timeslice      0 non-null      float64
#  11  Action         85917 non-null  object
#  12  Expression     19827 non-null  object
#  13  Scenario       52872 non-null  object
# dtypes: float64(3), int64(1), object(10)
# memory usage: 9.8+ MB

# %%
df_merge_clean.to_csv(r'C:\Users\Tom.Jamieson\Desktop\WPD Peak heat\Multi home inputs_py.csv', index = False)
